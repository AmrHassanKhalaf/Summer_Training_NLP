# %% [markdown]
# <a href="https://colab.research.google.com/github/AmrHassanKhalaf/Summer_Training_NLP/blob/main/Sec_7/Task_1/Sec_7_T_1_NTI_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
import re

# %%
df=pd.read_csv('/content/train_data.csv')

# %%
df
# Out:
#       Unnamed: 0                                         clean_text     target
# 0           7051  نفذ اليوم عدد من أهالي مكثر من ولاية سليانة وق...  localnews
# 1           6618  اتهم القيادي في نداء تونس منذر بلحاج ضيف بولتي...  localnews
# 2           6656  تذكر وزارة النقل في بلاغ صادر لها الثلاثاء وتف...  localnews
# 3           8078  أبرز الأحداث والمستجدات على الساحة الوطنية وال...  localnews
# 4           9768  أصدرت الهيئة العليا المستقلة للاتصال السمعي ال...  localnews
# ...          ...                                                ...        ...
# 8287        3087  تعقد اللجنة المنظمة لبطولة إفريقيا لأندية كرة ...      sport
# 8288        4496  تمكنت وحدات الحرس الوطني بنابل من إيقاف مرتكب ...    society
# 8289        6064  أعلنت وزارة الصناعة والمناجم والطاقات المتجددة...  localnews
# 8290        2329  قال نزار عياد محامي المدير التنفيذي لحركة نداء...    politic
# 8291        8303  قال غازي الشواشي مساعد رئيس مجلس نواب الشعب ال...  localnews
#
# [8292 rows x 3 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                                              clean_text     target
# 0     نفذ اليوم عدد من أهالي مكثر من ولاية سليانة وق...  localnews
# 1     اتهم القيادي في نداء تونس منذر بلحاج ضيف بولتي...  localnews
# 2     تذكر وزارة النقل في بلاغ صادر لها الثلاثاء وتف...  localnews
# 3     أبرز الأحداث والمستجدات على الساحة الوطنية وال...  localnews
# 4     أصدرت الهيئة العليا المستقلة للاتصال السمعي ال...  localnews
# ...                                                 ...        ...
# 8287  تعقد اللجنة المنظمة لبطولة إفريقيا لأندية كرة ...      sport
# 8288  تمكنت وحدات الحرس الوطني بنابل من إيقاف مرتكب ...    society
# 8289  أعلنت وزارة الصناعة والمناجم والطاقات المتجددة...  localnews
# 8290  قال نزار عياد محامي المدير التنفيذي لحركة نداء...    politic
# 8291  قال غازي الشواشي مساعد رئيس مجلس نواب الشعب ال...  localnews
#
# [8292 rows x 2 columns]

# %%
x=df['clean_text']
y=df['target']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(x.fillna(''))
print(X_train_tfidf.shape)
# Out:
# (8292, 73331)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(X_train_tfidf,y)
# Out:
# LinearSVC()

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf', TfidfVectorizer()),('clf', LinearSVC())])

text_clf.fit(x.fillna(''), y) # Fill NaN values with empty strings
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
import pickle

# Open the file in write-binary mode
with open("text_clf_model.pkl", "wb") as f:
    pickle.dump(text_clf, f)
